# %% [markdown]
# <a href="https://colab.research.google.com/github/bozhikov/SHE/blob/main/train1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
ys = 200 + np.random.randn(100)

# %%
x = [x for x in range(len(ys))]

# %%
plt.plot(x, ys, '-')

# %%
from google.colab import files

# %%
src = list(files.upload().values())[0]
# Out:
#      <input type="file" id="files-b0418f3f-4904-4577-9732-c23c681f3266" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0418f3f-4904-4577-9732-c23c681f3266">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving caam2013_11.xls to caam2013_11.xls

# %% [markdown]
# # Новый раздел

# %%
open('mylib.py','wb').write(src)
# Out:
# 41

# %%
f=open('caam2013_11.xls',mode='r')

# %%
print(f.read())

# %%
from google.colab import files
f = list(files.upload().values())[0]
# Out:
#      <input type="file" id="files-ab610f37-c439-46cd-974b-68468901b6fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab610f37-c439-46cd-974b-68468901b6fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 182Hg2Flow.txt to 182Hg2Flow.txt

# %%
import pandas as pd

# %%
data = {"name":["Sahil","Rob","Maya"],"age":[23,67,45]}

# %%
df = pd.DataFrame(data)

# %%
df.to_excel("person.xlsx",index=None)

# %%
print(df)
# Out:
#     name  age
# 0  Sahil   23
# 1    Rob   67
# 2   Maya   45

# %%
from traitlets.traitlets import Any
df1=pd.read_excel('EvacTimeGRANDCryo182Hg.txt.xlsx')

# %%
print(df1)
# Out:
#         currid   № beam  Ea chanel  strip     Time µsec
# 0           10      NaN        NaN    NaN           NaN
# 1           10      NaN        NaN    NaN           NaN
# 2           10      NaN        NaN    NaN           NaN
# 3           10      NaN        NaN    NaN           NaN
# 4            5      0.0      100.0   12.0  2.994160e+05
# ...        ...      ...        ...    ...           ...
# 136469      10      NaN        NaN    NaN           NaN
# 136470       5      0.0       79.0   12.0  6.802650e+09
# 136471      10      NaN        NaN    NaN           NaN
# 136472      10      NaN        NaN    NaN           NaN
# 136473      10      NaN        NaN    NaN           NaN
#
# [136474 rows x 5 columns]

# %%
from pandas.core.frame import DataFrame
df2=DataFrame(df1)

# %%
print(pd.df2(1,1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-dc154d76a274> in <module>()
# ----> 1 print(pd.df2(1,1))
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'df2'
