# %% [markdown]
# <a href="https://colab.research.google.com/github/bozhikov/SHE/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22URA_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path='/content/170ER09.000'
ab=open(path,'rb')
abv=ab.read()

# %%
import string

# %%
class input_file:
  ID,Time,F,A,FF,AA,FFF,AAA,FFFF,AAAA,Ftot,Atot=[],[],[],[],[],[],[],[],[],[],[],[]
  def  __init__(self,Currid_1byte,Time_hbyte,Time_lbyte,F_hbyte,F_lbyte,A_hbyte,A_lbyte):
       #ff=[] 
       self.Currid=Currid_1byte
       self.ID.append(Currid_1byte)
       self.Time_hbyte=Time_hbyte
       self.Time.append(Time_hbyte)
       self.Time_lbyte=Time_lbyte
       self.Time.append(Time_lbyte)
       self.F_hbyte=F_hbyte
       self.F.append(F_hbyte)
       self.F_lbyte=F_lbyte
       self.F.append(F_lbyte)
       self.A_hbyte=A_hbyte
       self.A.append(A_hbyte)
       self.A_lbyte=A_lbyte
       self.A.append(A_lbyte)
   #convert to :
  def data_bin(self):
     for F in self.F:
       self.FF.append(bin(F))
     for A in self.A:
       self.AA.append(bin(A))
  
  def convertor(self):
    import string
    for i in range(len(self.FF)):
      self.FFF.append(str(self.FF[i]).lstrip('0b'))
    for j in range(len(self.AA)):
      self.AAA.append(str(self.AA[j]).lstrip('0b'))
    for FFF in self.FFF:
      self.FFFF.append(FFF.zfill(8))
    for AAA in self.AAA: 
      self.AAAA.append(AAA.zfill(8))
    #for k in range(0,len(self.FF),2):
     #value=str(self.FF[i])+str(self.FF[i+1])      #lstr  #.zfill(8)
     #self.FFF.append(str(self.FF[i])+str(self.FF[i+1]))

    #AAA=str(self.AA).lstrip('0b').zfill(8)
  def total_join_data(self):
    for k in range(0,len(self.FFFF),2):
      self.Ftot.append(self.FFFF[i]+self.FFFF[i+1])
    for l in range(0,len(self.AAAA),2):
      self.Atot.append(self.AAAA[l]+self.AAAA[i+1])

# %%
for i in range(0,len(abv),8):
  s=input_file(abv[i],abv[i+3],abv[i+2],abv[i+5],abv[i+4],abv[i+7],abv[i+6])

# %%
s.data_bin()

# %%
s.convertor()

# %%
s.total_join_data
s.Atot
s.FFFF
# Out:
# ['00010000',
#  '00111100',
#  '01110000',
#  '01000001',
#  '10110000',
#  '00000100',
#  '11100000',
#  '01011101',
#  '11000000',
#  '01101110',
#  '10000000',
#  '01001001',
#  '00100000',
#  '00110101',
#  '01000000',
#  '01101100',
#  '00000000',
#  '01100101',
#  '01100000',
#  '00111110',
#  '00010000',
#  '00101101',
#  '00010000',
#  '00101000',
#  '01000000',
#  '00101111',
#  '01010000',
#  '01110101',
#  '10010000',
#  '01101011',
#  '00010001',
#  '00001110',
#  '00110000',
#  '01111101',
#  '01110000',
#  '01101100',
#  '00110000',
#  '01101001',
#  '01100000',
#  '01001100',
#  '00000000',
#  '01010010',
#  '10000000',
#  '00110010',
#  '10000000',
#  '00101010',
#  '11100000',
#  '00111111',
#  '10000000',
#  '01000101',
#  '00010000',
#  '00111110',
#  '10100000',
#  '00110111',
#  '11010000',
#  '01100001',
#  '00110000',
#  '01101011',
#  '11110000',
#  '10000001',
#  '01010000',
#  '01100001',
#  '00100000',
#  '01000110',
#  '10100000',
#  '00111101',
#  '00100000',
#  '00110000',
#  '00100000',
#  '00010101',
#  '01100000',
#  '01100101',
#  '11010000',
#  '01010110',
#  '10010000',
#  '01010111',
#  '00110000',
#  '01011101',
#  '10010000',
#  '00011101',
#  '11100000',
#  '00011110',
#  '10100000',
#  '00010101',
#  '00110000',
#  '00011010',
#  '11100000',
#  '00111100',
#  '11000000',
#  '01001000',
#  '10110000',
#  '00110110',
#  '11100000',
#  '00101111',
#  '11000001',
#  '01000000',
#  '00000001',
#  '00011110',
#  '00110000',
#  '01000101',
#  '00110000',
#  '01000000',
#  '00000000',
#  '00000000',
#  '10010000',
#  '00110011',
#  '01110000',
#  '00111000',
#  '10000000',
#  '01101111',
#  '11000000',
#  '01100101',
#  '11010000',
#  '01011010',
#  '01010000',
#  '00111111',
#  '00000000',
#  '01000010',
#  '11010000',
#  '01011110',
#  '00000000',
#  '01100111',
#  '11110000',
#  '10000010',
#  '01010000',
#  '00100000',
#  '10000000',
#  '01100100',
#  '00010000',
#  '01000101',
#  '10100000',
#  '01100011',
#  '00110000',
#  '01101010',
#  '01010000',
#  '00100111',
#  '00000000',
#  '00101101',
#  '00000000',
#  '00000011',
#  '11000000',
#  '01110101',
#  '10100000',
#  '01010101',
#  '01000000',
#  '01111101',
#  '01100000',
#  '01100001',
#  '00110000',
#  '00100100',
#  '01010000',
#  '00011110',
#  '01000000',
#  '01110100',
#  '00000000',
#  '01101100',
#  '01010000',
#  '01000110',
#  '00110000',
#  '01001110',
#  '00000000',
#  '00000000',
#  '10100000',
#  '01000001',
#  '00110000',
#  '00011110',
#  '00010000',
#  '01011111',
#  '01100000',
#  '01011001',
#  '11110000',
#  '00011010',
#  '01000000',
#  '00011010',
#  '10100000',
#  '01100010',
#  '11000000',
#  '01101110',
#  '01010000',
#  '01000010',
#  '11010000',
#  '00110111',
#  '00100000',
#  '01001100',
#  '01000000',
#  '01010101',
#  '01110000',
#  '00110010',
#  '00110000',
#  '00010101',
#  '00110000',
#  '01001100',
#  '00000000',
#  '01001001',
#  '01000000',
#  '01101001',
#  '01010000',
#  '01000100',
#  '00110000',
#  '01101010',
#  '01000000',
#  '01100100',
#  '00000000',
#  '00111111',
#  '01010000',
#  '00110011',
#  '10000000',
#  '01000111',
#  '10100000',
#  '00110010',
#  '00000000',
#  '00110100',
#  '01100000',
#  '00101010',
#  '10000011',
#  '01000001',
#  '11100010',
#  '01101110',
#  '11000000',
#  '00111000',
#  '11110000',
#  '00101110',
#  '10110000',
#  '01000000',
#  '11110000',
#  '00111110',
#  '11010000',
#  '01100001',
#  '00100000',
#  '01011001',
#  '01110000',
#  '01001010',
#  '10100000',
#  '00111000',
#  '01010000',
#  '01100000',
#  '00000000',
#  '01100011',
#  '01010000',
#  '01000100',
#  '10010000',
#  '00111110',
#  '00000000',
#  '00000000',
#  '11110000',
#  '00111110',
#  '10100000',
#  '00101110',
#  '11110000',
#  '01110010',
#  '10000000',
#  '01100101',
#  '10110000',
#  '01101100',
#  '01110000',
#  '01100011',
#  '11010000',
#  '01100001',
#  '01110000',
#  '01100000',
#  '10100000',
#  '01001100',
#  '11000000',
#  '01010110',
#  '00100000',
#  '01010010',
#  '01110000',
#  '01010111',
#  '01010000',
#  '00101111',
#  '11100000',
#  '00101110',
#  '10100001',
#  '00101011',
#  '01100001',
#  '00000111',
#  '00010000',
#  '01100000',
#  '01110000',
#  '01100111',
#  '00100000',
#  '00101000',
#  '00110000',
#  '00101101',
#  '10100000',
#  '01100011',
#  '00110000',
#  '01101010',
#  '00010000',
#  '11010111',
#  '01010000',
#  '00110111',
#  '11000000',
#  '00000100',
#  '11000000',
#  '01110001',
#  '11110000',
#  '01100110',
#  '11000000',
#  '01110011',
#  '10110000',
#  '01100101',
#  '00000000',
#  '00001110',
#  '10000000',
#  '00001100',
#  '01000000',
#  '01111001',
#  '01010000',
#  '01011111',
#  '00110000',
#  '00110011',
#  '00010000',
#  '00101000',
#  '11010000',
#  '01011111',
#  '01010000',
#  '01010111',
#  '11010000',
#  '01011101',
#  '11010000',
#  '01001100',
#  '11010000',
#  '01100010',
#  '00110000',
#  '00101101',
#  '10110000',
#  '00111011',
#  '01100000',
#  '00110010',
#  '10100000',
#  '01100011',
#  '10010000',
#  '01011000',
#  '10010000',
#  '00000011',
#  '10110000',
#  '10000111',
#  '01100000',
#  '01101101',
#  '00000000',
#  '01110000',
#  '10010000',
#  '01001111',
#  '00000000',
#  '00000000',
#  '11010000',
#  '01011001',
#  '01010000',
#  '00010110',
#  '11110000',
#  '01011001',
#  '10110000',
#  '00111110',
#  '00110000',
#  '01110010',
#  '00100000',
#  '01011001',
#  '10010000',
#  '01001101',
#  '11000000',
#  '01011001',
#  '01000000',
#  '01011101',
#  '01010000',
#  '01001000',
#  '01100000',
#  '01001011',
#  '10000000',
#  '01001101',
#  '10110000',
#  '01000010',
#  '01100000',
#  '00110011',
#  '10100000',
#  '01010000',
#  '01100000',
#  '01001001',
#  '00000000',
#  '00101111',
#  '11010000',
#  '00100101',
#  '00111011',
#  '01010011',
#  '00001001',
#  '11110010',
#  '01110000',
#  '01000100',
#  '01010000',
#  '00111000',
#  '10010000',
#  '00111010',
#  '00000000',
#  '01000100',
#  '01000000',
#  '01010001',
#  '10000000',
#  '01001000',
#  '11000000',
#  '10010011',
#  '01110000',
#  '01111010',
#  '11100000',
#  '00111001',
#  '01100000',
#  '00110101',
#  '01010000',
#  '01100001',
#  '11110000',
#  '01101010',
#  '01110001',
#  '00101111',
#  '01100000',
#  '11101111',
#  '10110000',
#  '01011111',
#  '01010000',
#  '01001110',
#  '10000000',
#  '00000111',
#  '00000000',
#  '00000000',
#  '01010000',
#  '01001001',
#  '01010000',
#  '01000100',
#  '11000001',
#  '00001010',
#  '01110000',
#  '11100100',
#  '01100000',
#  '00101110',
#  '01100000',
#  '00101001',
#  '00110000',
#  '01011001',
#  '00100000',
#  '01000110',
#  '01100000',
#  '00101110',
#  '01100000',
#  '00101010',
#  '10000000',
#  '10001100',
#  '10000000',
#  '01101100',
#  '01110000',
#  '10001001',
#  '00010000',
#  '01101011',
#  '11100000',
#  '01001000',
#  '10110000',
#  '01001111',
#  '00110001',
#  '00011101',
#  '01000001',
#  '00001001',
#  '00000000',
#  '00010111',
#  '10110000',
#  '00010101',
#  '10010000',
#  '01011011',
#  '01010000',
#  '01011001',
#  '10100000',
#  '01011000',
#  '01110000',
#  '01011010',
#  '00000000',
#  '00000000',
#  '10100000',
#  '00100110',
#  '00110000',
#  '00101011',
#  '10000000',
#  '01100111',
#  '10110000',
#  '01010111',
#  '11010000',
#  '01100111',
#  '00100000',
#  '01011101',
#  '10000000',
#  '01001100',
#  '10100000',
#  '00110101',
#  '10110000',
#  '01100011',
#  '00010000',
#  '01001111',
#  '11000000',
#  '01010101',
#  '11100000',
#  '00111110',
#  '01110000',
#  '01100000',
#  '10100000',
#  '01001010',
#  '11000000',
#  '01110101',
#  '11010000',
#  '01010001',
#  '10000000',
#  '00001010',
#  '11010000',
#  '00001001',
#  '11000000',
#  '01100010',
#  '10110000',
#  '01010110',
#  '10000000',
#  '01111001',
#  '01100000',
#  '01010110',
#  '11010000',
#  '01011010',
#  '10000000',
#  '01011101',
#  '01000000',
#  '01110001',
#  '01010000',
#  '00101111',
#  '11010000',
#  '00001010',
#  '10000000',
#  '00001011',
#  '11100000',
#  '01000110',
#  '01110000',
#  '01001101',
#  '01100001',
#  '00101000',
#  '10100000',
#  '10110110',
#  '10110000',
#  '01010111',
#  '00010000',
#  '01000110',
#  '11100000',
#  '01011101',
#  '10000000',
#  '01100101',
#  '01100000',
#  '01010001',
#  '01010000',
#  '01001000',
#  '11010000',
#  '01100001',
#  '11110000',
#  '01101001',
#  '10110000',
#  '01010101',
#  '11010000',
#  '00111111',
#  '01000000',
#  '01101010',
#  '10000000',
#  '00110011',
#  '00000000',
#  '00001010',
#  '00000000',
#  '00000000',
#  '00100000',
#  '00110100',
#  '11010000',
#  '00110000',
#  '10010000',
#  '00000110',
#  '10100000',
#  '01000011',
#  '01010000',
#  '00111110',
#  '00010000',
#  '01000001',
#  '11000000',
#  '01001110',
#  '11010000',
#  '00000111',
#  '01000000',
#  '01011000',
#  '00110000',
#  '01010011',
#  '11110001',
#  '00011000',
#  '01000000',
#  '11100011',
#  '01000000',
#  '10100001',
#  '00000000',
#  '10010110',
#  '00110000',
#  '01010000',
#  '01100000',
#  '00111111',
#  '01010000',
#  '01001101',
#  '01110000',
#  '01010010',
#  '10000000',
#  '01011100',
#  '01010000',
#  '01000100',
#  '10100000',
#  '01101000',
#  '01100000',
#  '01001011',
#  '01100000',
#  '00100110',
#  '01100000',
#  '00100010',
#  '01010000',
#  '00001101',
#  '00000000',
#  '00010010',
#  '00110000',
#  '01011001',
#  '11100000',
#  '01001001',
#  '01100000',
#  '01100001',
#  '10010000',
#  '01011011',
#  '01110000',
#  '01100001',
#  '01010000',
#  '01100000',
#  '10000000',
#  '00110100',
#  '00000000',
#  '00000000',
#  '00110000',
#  '00000110',
#  '11000000',
#  '01010011',
#  '10100000',
#  '00111100',
#  '11010000',
#  '01100010',
#  '01110000',
#  '01100011',
#  '10010000',
#  '01000101',
#  '00000000',
#  '01000100',
#  '10100000',
#  '00011110',
#  '11110000',
#  '00100001',
#  '10000000',
#  '00110011',
#  '11000000',
#  '00101111',
#  '10000000',
#  '01111001',
#  '01100000',
#  '01010010',
#  '00100000',
#  '01101010',
#  '11010000',
#  '01011110',
#  '10000000',
#  '10010110',
#  '01100000',
#  '01100001',
#  '10110000',
#  '01000011',
#  '11110000',
#  '01000001',
#  '00100000',
#  '01000111',
#  '11100000',
#  '01000100',
#  '10110000',
#  '00000011',
#  '01000000',
#  '01001101',
#  '00000000',
#  '01000011',
#  '10110000',
#  '01100000',
#  '11100000',
#  '01010001',
#  '11110000',
#  '10001000',
#  '01000000',
#  '01111111',
#  '01000000',
#  '01100110',
#  '01010000',
#  '01010000',
#  '00100000',
#  '01100001',
#  '10000000',
#  '01100100',
#  '00010000',
#  '01010111',
#  '10100000',
#  '01001110',
#  '10110000',
#  '00111111',
#  '10000000',
#  '00111101',
#  '10110000',
#  '10000111',
#  '10000000',
#  '01001011',
#  '10010000',
#  '00110110',
#  '10100001',
#  '00010001',
#  '01100000',
#  '11100110',
#  '01111001',
#  '11111101',
#  '10010111',
#  '11100010',
#  '00000000',
#  '00000000',
#  '01100000',
#  '01010011',
#  '01000000',
#  '01011001',
#  '01110010',
#  '10100010',
#  '10010010',
#  '00000011',
#  '01110000',
#  '01101111',
#  '00010000',
#  '01010111',
#  '10000000',
#  '10000101',
#  '00010000',
#  '01011111',
#  '10000000',
#  '01110000',
#  '00110000',
#  '01100100',
#  '10000001',
#  '01000110',
#  '00110000',
#  '01110101',
#  '01000000',
#  '01011010',
#  '01010000',
#  '01000111',
#  '11110000',
#  '01011001',
#  '01000000',
#  '00100100',
#  '01100000',
#  '11011011',
#  '10000000',
#  '11011010',
#  '11010000',
#  '00111001',
#  '01100000',
#  '00110101',
#  '10010000',
#  '01000110',
#  '11110000',
#  '01001000',
#  '11010000',
#  '01010110',
#  '01000000',
#  '01100000',
#  '10110000',
#  '01010111',
#  '10110000',
#  '01010010',
#  '10100000',
#  '01001010',
#  '11000000',
#  '01010011',
#  '00100000',
#  '01000111',
#  '11000000',
#  '01010001',
#  '00100000',
#  '01010101',
#  '00100000',
#  '01001111',
#  '01010000',
#  '00010110',
#  '01000000',
#  '00011011',
#  '01100000',
#  '00000111',
#  '01000000',
#  '01110010',
#  '01110000',
#  '01100110',
#  '10110000',
#  '01010011',
#  '00010000',
#  '01000100',
#  '10000000',
#  '01100111',
#  '10110000',
#  '01010110',
#  '10110000',
#  '00010110',
#  '00000000',
#  '00010111',
#  '00000000',
#  '01110001',
#  '01110000',
#  '01100111',
#  '11000000',
#  '00001010',
#  '00110000',
#  '00001010',
#  '01000000',
#  '01110001',
#  '01010000',
#  '01011000',
#  '00000000',
#  '00000000',
#  '10010000',
#  '00111001',
#  '10010000',
#  '00110100',
#  '11110000',
#  '00001011',
#  '11110000',
#  '00000110',
#  '10100000',
#  '00101110',
#  '11010000',
#  '00101010',
#  '10000000',
#  '00001100',
#  '00010000',
#  '00001010',
#  '11010000',
#  '00100011',
#  '11010000',
#  '00100000',
#  '10100000',
#  '01001010',
#  '01010000',
#  '01000100',
#  '10010000',
#  '11100111',
#  '00010000',
#  '11001110',
#  '10100001',
#  '00000111',
#  '00000001',
#  '00010101',
#  '00010000',
#  '00100111',
#  '01010000',
#  '00100110',
#  '10000000',
#  '10010000',
#  '01100000',
#  '01101001',
#  '01000000',
#  '00001001',
#  '10110000',
#  '00000111',
#  '01000000',
#  '01001001',
#  '11110000',
#  '00111101',
#  '10010000',
#  '01100000',
#  '01000000',
#  '01101100',
#  '00110000',
#  '01110010',
#  '00010000',
#  '01011000',
#  '10000000',
#  '01111010',
#  '10100000',
#  '01010101',
#  '11010000',
#  '01011111',
#  '00110000',
#  '00110010',
#  '01100000',
#  '00000100',
#  '11010000',
#  '01010010',
#  '00110000',
#  '01011011',
#  '00000000',
#  '00000000',
#  '01010001',
#  '00011110',
#  '01110000',
#  '01101111',
#  '10110000',
#  '01100101',
#  '11110000',
#  '01000100',
#  '00110000',
#  '00011010',
#  '00000000',
#  '11101100',
#  '00000000',
#  '00000101',
#  '00110000',
#  '00000101',
#  '10110000',
#  '00011100',
#  '01000000',
#  '00100000',
#  '10100000',
#  '01100101',
#  '10110000',
#  '01101000',
#  '11000001',
#  '00100101',
#  '01100000',
#  '11011011',
#  '00110000',
#  '01110001',
#  '10010000',
#  '01010110',
#  '00100000',
#  '01011101',
#  '10110000',
#  '01100001',
#  '01100001',
#  '00010101',
#  '00010000',
#  '11100000',
#  '00110000',
#  '01110010',
#  '11000000',
#  '01101110',
#  '00000000',
#  '01001100',
#  '10100000',
#  '00111001',
#  '01000000',
#  '01111000',
#  '11100000',
#  '01010101',
#  '10100000',
#  '01100010',
#  '11100000',
#  '01011001',
#  '10100000',
#  '01011110',
#  '01100000',
#  '01010110',
#  '10110000',
#  '00011100',
#  '01000000',
#  '00011111',
#  '00010000',
#  '01011111',
#  '00110000',
#  '01101010',
#  '11100000',
#  '00111100',
#  '10100000',
#  '00110111',
#  '00110000',
#  '01010111',
#  '11100000',
#  '01000111',
#  '00010000',
#  '01011111',
#  '11010000',
#  '01010111',
#  '11100000',
#  '01001011',
#  '01000000',
#  '01011000',
#  '11010000',
#  '01000111',
#  '11100000',
#  '01000100',
#  '00000000',
#  '01110001',
#  '01100000',
#  '01011001',
#  '00110000',
#  '00110100',
#  '11000000',
#  '00101110',
#  '00000000',
#  '00000000',
#  '10000001',
#  '00100100',
#  '01100000',
#  '11010010',
#  '00110000',
#  '01100000',
#  '01100000',
#  '01001001',
#  '01010000',
#  '01100001',
#  ...]

# %%
class bin_to_string(input_file):
  def YX(self):
    input_file.__init__(self,Currid_1byte,Time_hbyte,Time_lbyte,F_hbyte,F_lbyte,A_hbyte,A_lbyte)

# %%
bin_to_string()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-a22b480acfbf> in <module>
# ----> 1 bin_to_string()
#
# TypeError: __init__() missing 7 required positional arguments: 'Currid_1byte', 'Time_hbyte', 'Time_lbyte', 'F_hbyte', 'F_lbyte', 'A_hbyte', and 'A_lbyte'

# %%
bin_to_string()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-a22b480acfbf> in <module>
# ----> 1 bin_to_string()
#
# TypeError: __init__() missing 2 required positional arguments: 'FF' and 'AA'

# %%
bin_to_string.CC
# Out:
# []

# %%
len(s.Time)
# Out:
# 766546

# %%
import string

# %%
s.FF[766545]
# Out:
# '0b1100110'

# %%
FFF=str(s.FF[766544]).lstrip('0b')

# %%
FFFF=FFF.zfill(8)

# %%
len(FFFF)
# Out:
# 8

# %%
class primery_data:

  def __init__(self, aple):
      self.aple =aple
  def input_data(self,currid,Time,Fis,Alfa):
        self.currid =10
        self.Time =Time
        self.Fis =[]
        self.Fis =Alfa
for i in range(len(abv),8):
                       TTime.append(abv[i-1,i])
#class Genre(Enum):
#    undefined = GenreItem(0, [])
#    pop = GenreItem(1, ["Поп и Эстрада"])

#for i in Genre:
#    item = i.value
#     print(item.id, item.values)

# %%
ff=primery_data(2)
ff.aple
ff.currid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-205-b821e1c92d34> in <module>
#       1 ff=primery_data(2)
#       2 ff.aple
# ----> 3 ff.currid
#
# AttributeError: 'primery_data' object has no attribute 'currid'

# %%
for a ran
a
# Out:
# 3066184

# %%
abv[3066183]
# Out:
# 8

# %%
abv[1]
# Out:
# 0

# %%
abv[2]
# Out:
# 72

# %%
abv[3]
# Out:
# 200

# %%
abv[408]
# Out:
# 10

# %%
bin(abv[3])
# Out:
# '0b11001000'

# %%
a13=bin(abv[3])
a13
# Out:
# '0b11001000'

# %%
a14=bin(abv[4])
a14
# Out:
# '0b111100'

# %%
AA1=str(a14) + str(a13)
AA1
# Out:
# '0b1111000b11001000'

# %%
import string
a14b = str(a14).lstrip('0b')
a13b = str(a13).lstrip('0b')
AA1b = a14b.zfill(8) + a13b.zfill(8)
AA1b
# Out:
# '0011110011001000'

# %%
a=abv[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-47e7de0b1fc9> in <module>
# ----> 1 a=abv[1]
#
# NameError: name 'abv' is not defined

# %%
#@title
import pandas as pd
abv= ab.read()
abv
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-696dd629169c> in <module>
#       1 #@title
#       2 import pandas as pd
# ----> 3 abv= ab.read()
#       4 abv
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb5 in position 28: invalid start byte

# %% [markdown]
# Spectroscopy LOOP

# %%
s=abv['draft1']
s[3]
# Out:
# 32.5054445228847

# %%
s[2]+s[4]
# Out:
# 65.1570400467217

# %% [markdown]
# Spectroscopy Loop

# %%
class Counts_data:
  def __init__(self,Currid, Time, Strip, E):
    self.Currid =Currid;
    self.Time = Time;
    self.Strip = Strip;
    self.E = E;
    def Determine_data(self,*abv):
     self.Time = str(abv).lstrip('0b')
    
    return self.Time

Counts_data(20,2,4,34)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4cbbc6ba2f60> in <module>
#      10     return self.Time
#      11
# ---> 12 Counts_data(20,2,4,34)
#
# TypeError: __init__() should return None, not 'int'

# %%
a=list(abv)

# %%
abv1=list(abv)
abv1[0]
# Out:
# 1

# %%
class Protocol:
  print('Insurte protocol')
# input protocol
# determine ID
  def __init__(self,Currid):

    self.Currid=[]
    t=0
    for y in abv1:
     t=t
    Currid=abv1[t]

# Her
     
  def Descriptor(self,TTop,FTop,ATop):
    self.TTop=10
    self.FTop=[]
    self.ATop=[]
# Out:
# Insurte protocol

# %% [markdown]
# # Новый раздел

# %%
z=Protocol(abv)
z.TTop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-dfb5df6f7dba> in <module>
#       1 z=Protocol(abv)
# ----> 2 z.TTop
#
# AttributeError: 'Protocol' object has no attribute 'TTop'

# %% [markdown]
# [Текст ссылки](https://)# to open bynary fails

# %%
path='/randomdata_250222 (1).xlsx'

# %%
data1=pd.read_excel(path,sheet_name=1,usecols=[7,8])

# %%
print(data1)
# Out:
#    34.482384  33.140733  33.140011  32.323887  32.023198  33.368251  \
# 0  32.542978  33.160010  32.439330  31.761147  33.801132  33.304248
# 1  32.795069  31.945372  32.370778  33.122488  32.354443  32.963448
# 2  32.673130  32.612449  32.505445  32.256014  32.821697  32.492202
# 3  33.117446  32.515436  32.786262  34.026080  31.566236  32.452334
# 4  33.086105  32.091760  32.966322  33.356744  31.975881  33.582099
# 5  32.782067  33.334094  32.321941  32.636339  32.878964  34.109519
# 6  34.078097  32.117584  32.637722  31.775159  33.448407  32.873780
# 7  32.574171  32.561304  31.941075  32.234262  33.247773  32.787261
# 8  33.052918  32.875247  32.845885  32.854395  33.454851  32.802123
#
#    32.733751  33.275458  32.327856  33.433411  ...  33.401760  32.930499  \
# 0  32.533154  32.932568  32.712923  31.924491  ...  32.564022  32.490947
# 1  34.125859  33.368971  33.523915  34.370611  ...  34.108799  32.281020
# 2  33.782787  33.010737  33.513681  32.770508  ...  33.799862  32.881082
# 3  32.739166  32.954896  31.718317  33.198603  ...  32.694056  32.083331
# 4  34.437881  31.862933  31.537345  32.813537  ...  32.758577  32.864159
# 5  33.153775  32.604440  32.715754  32.680619  ...  32.353305  33.013996
# 6  32.668422  31.758550  32.977396  32.693771  ...  32.372329  32.699808
# 7  33.349319  33.288734  33.100502  33.350658  ...  33.132623  32.832524
# 8  31.169667  32.548864  32.985421  33.474222  ...  33.346956  33.012269
#
#    32.116895  32.605577  33.022748  33.632985  32.198533  33.688894  \
# 0  32.318580  31.696969  32.526092  32.963319  32.180441  33.148316
# 1  32.423423  34.151707  33.150780  32.833053  33.153227  32.690948
# 2  33.943186  33.164466  33.095859  34.262880  33.842838  33.440647
# 3  33.899712  33.099048  32.699429  32.267708  32.923143  33.937939
# 4  32.178651  31.807894  33.872192  33.047273  32.099931  33.548600
# 5  32.799427  33.367670  33.474041  33.555746  33.274188  33.264832
# 6  31.804792  32.743526  33.254040  32.618928  32.413257  33.054638
# 7  32.064952  32.536831  33.068545  32.148689  33.159638  33.066472
# 8  32.726641  32.875833  32.842022  32.949830  33.012055  32.430209
#
#    34.631599  0.000000
# 0  32.685409          0
# 1   0.000000          0
# 2   0.000000          0
# 3  33.036166          0
# 4  32.029682          0
# 5   0.000000          0
# 6  33.564691          0
# 7  32.924014          0
# 8  32.191200          0
#
# [9 rows x 22 columns]

# %%
aaa=[]
primes = [2, 3, 5]
for prime in primes:
    prime=prime*prime
    
    aaa.append(prime)
aaa
# Out:
# [4, 9, 25]

# %%
aaa[1]
# Out:
# 9

# %%
for a in range(len(abv),8):
